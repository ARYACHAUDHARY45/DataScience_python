# %%
name="Harry"

# %%
name
# Out:
# 'Harry'

# %%
name.upper()
# Out:
# 'HARRY'

# %%
name.endswith("ry")
# Out:
# True

# %%
name.endswith("yuh")
# Out:
# False

# %%
name.lower()
# Out:
# 'harry'

# %%
name.count("a")
# Out:
# 1

# %%
name.count("r")
# Out:
# 2

# %%
name[0:4]#slicing
# Out:
# 'Harr'

# %%
name[1:-1]
# Out:
# 'arr'

# %%
s="hello world"

# %%
s.replace("world" , "arya")
# Out:
# 'hello arya'

# %%
s.split()
# Out:
# ['hello', 'world']

# %%
a=['hello', 'world']

# %%
s.join(a)
# Out:
# 'hellohello worldworld'

# %%
s.isdigit()
# Out:
# False

# %%
s.isalpha()
# Out:
# False

# %%
str="arya"

# %%
str.isalpha()
# Out:
# True

# %%
str.isalnum()
# Out:
# True

# %%
surname="Patel"

# %%
firstname="Arya"

# %%
print(f"Hello {surname} {firstname}")
# Out:
# Hello Patel Arya
