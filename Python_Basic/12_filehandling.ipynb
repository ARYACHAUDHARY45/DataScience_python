# %% [markdown]
# ## File handling

# %%
f=open("text.txt","r")

# %%
content = f.read()

# %%
print(content)
# Out:
# Arya

# %%
f.close()

# %%
s="this is a python."

# %%
file=open("text.txt","w")

# %%
file.write(s)
# Out:
# 17

# %%
file.close()

# %%
file=open("text.txt","a")

# %%
file.write("\n this is new line.")
# Out:
# 19

# %%
file.close()

# %%
import os

# %%
os.path.exists("new.txt") #check file exist or not
# Out:
# True

# %%
os.remove("new.txt")  #remove file if exists otherwise throw error.

# %%
with open("example.txt", "w") as file:
    content = file.write("hii")
    print(content)  # No need to manually close the file and this is best practice
# Out:
# 3
