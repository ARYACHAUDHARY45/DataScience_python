# %% [markdown]
# ## List and List Methods..

# %%
# Empty list
my_list = []

# List with elements
numbers = [1, 2, 3, 4, 5]

# Mixed data types
mixed_list = [1, "Hello", 3.14, True]

# %%
l=[23,45,3,2]

# %%
l[3]
# Out:
# 2

# %%
l[0]=4  #list is mutable

# %%
l
# Out:
# [4, 45, 3, 2]

# %%
l.append(9)

# %%
l
# Out:
# [4, 45, 3, 2, 9]

# %%
# most of list methods will change original list instead of creating new list..

# %%
l2=[2,3]

# %%
l.extend(l2)

# %%
l
# Out:
# [4, 45, 3, 2, 9, 2, 3]

# %%
l.insert(1,2000)  #insert 2000 at 1 index..

# %%
l
# Out:
# [4, 2000, 45, 3, 2, 9, 2, 3]

# %%
number = l.pop(4) #remove element at index 4 and return it ..

# %%
number
# Out:
# 2

# %%
l
# Out:
# [4, 2000, 45, 3, 9, 2, 3]

# %%
l.index(4)
# Out:
# 0

# %%
l.count(3)
# Out:
# 2

# %%
l.count(2000)
# Out:
# 1

# %%
l.count(10)
# Out:
# 0

# %%
l.sort()

# %%
l
# Out:
# [2, 3, 3, 4, 9, 45, 2000]

# %%
new=[34,21,2,200]

# %%
sorted(new) # Gives another sorted list without changing original...
# Out:
# [2, 21, 34, 200]

# %%
new
# Out:
# [34, 21, 2, 200]

# %%
y=[2,3,4,[121,32],True] #nested list

# %%
y[4]
# Out:
# True

# %%
y[3]
# Out:
# [121, 32]

# %%
y[3][1]
# Out:
# 32

# %%
l=[1,2,3]
m=[4,5,6,]

# %%
l+m #returns new list
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l
# Out:
# [1, 2, 3]

# %%
m
# Out:
# [4, 5, 6]

# %%
if 3 in l:
    print("yes")
# Out:
# yes

# %%
if 33 in l:
    print("yes")
else : 
    print("no")
# Out:
# no

# %%
s= "arya-javed-salma-yug-priyam-harsh"

# %%
s.split("-")
# Out:
# ['arya', 'javed', 'salma', 'yug', 'priyam', 'harsh']
