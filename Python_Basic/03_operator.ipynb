# %% [markdown]
# # Arithmatic operator

# %%
a=10
b=5

# %%
a+b
# Out:
# 15

# %%
a*b
# Out:
# 50

# %%
a-b
# Out:
# 5

# %%
a/b  #divide always give decimal number
# Out:
# 2.0

# %%
a//b #gives only integer part
# Out:
# 2

# %%
a%b #shows reminder
# Out:
# 0

# %%
2**3 #exponential operator
# Out:
# 8

# %% [markdown]
# # Comparison operator

# %%
#return true or false

# %%
c=23
d=45

# %%
c==d
# Out:
# False

# %%
c<=d
# Out:
# True

# %%
c>=d
# Out:
# False

# %%
c!=d
# Out:
# True

# %% [markdown]
# # Logical operator

# %%
#operates on boolean

# %%
b1= True
b2= False

# %%
not(b1)
# Out:
# False

# %%
b1 and b2
# Out:
# False

# %%
b1 or b2
# Out:
# True

# %% [markdown]
# # bitwise operator

# %%
#operates on each bit....

# %% [markdown]
# ## Assingment and Membership operators are there
