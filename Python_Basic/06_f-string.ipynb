# %%
name="arya"
age=20

# %%
#string format using format function.
print("My name is {} and i am {} year old.".format(name,age))
# Out:
# My name is arya and i am 20 year old.

# %%
#string format using f string.
print(f"My name is {name} and i am {age} year old.")
# Out:
# My name is arya and i am 20 year old.
