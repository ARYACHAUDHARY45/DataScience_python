# %% [markdown]
# ## Set and Set Methods

# %%
# Empty set (must use set(), not {})
empty_set = set()

# Set with elements
numbers = {1, 2, 3, 4, 5}

# Mixed data types
mixed_set = {1, "Hello", 3.14, True}

# Creating a set from a list
unique_numbers = set([1, 2, 2, 3, 4, 4, 5])
print(unique_numbers)  # {1, 2, 3, 4, 5}
# Out:
# {1, 2, 3, 4, 5}

# %%
a={}

# %%
type(a)
# Out:
# dict

# %%
b=set() #empty set creation.

# %%
type(b)
# Out:
# set

# %%
list=[1,22,22,22,34,56]

# %%
unique=set(list) #typecasting

# %%
print(unique)
# Out:
# {56, 1, 34, 22}

# %%
s={1,34,21,33}

# %%
s.add(67)

# %%
s
# Out:
# {1, 21, 33, 34, 67}

# %%
s.update([21,21,333,2000]) #add more iteam at once

# %%
s
# Out:
# {1, 21, 33, 34, 67, 333, 2000}

# %%
s.remove(21) #throw erreo if element not found.

# %%
s.discard(2) # not throw throw erreo if element not found.

# %%
set1={1,2,3,4}
set2={3,4,5,6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
sub={1,3}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True
