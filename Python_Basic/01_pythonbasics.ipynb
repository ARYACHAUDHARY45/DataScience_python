# %%
a=10

# %%
b=32

# %%
a+b
# Out:
# 42

# %%
name="arya"

# %%
print("hello")
# Out:
# hello

# %%
#this is a single line comment but we will use markdown language

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a="121"

# %%
b="21"

# %%
a+b
# Out:
# '12121'

# %%
int(a) + int(b) #typecasting in python
# Out:
# 142
