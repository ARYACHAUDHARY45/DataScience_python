# %%
# Empty dictionary
empty_dict = {}

# Dictionary with key-value pairs
student = {
    "name": "Alice",
    "age": 25,
    "grade": "A"
}

# Using dict() constructor
person = dict(name="John", age=30, city="New York")

# %%
student["name"]
# Out:
# 'Alice'

# %%
student.get("name") #this does not throw error if key is not present..
# Out:
# 'Alice'

# %%
student["age"]=33 #modify keys..

# %%
student["age"]
# Out:
# 33

# %%
print(student)
# Out:
# {'name': 'Alice', 'age': 33, 'grade': 'A'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Alice', 33, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'Alice'), ('age', 33), ('grade', 'A')])

# %%
a=student.pop("age2","notfound") #remove and return value of pair..

# %%
a
# Out:
# 'notfound'

# %%
student
# Out:
# {'name': 'Alice', 'grade': 'A'}

# %%
student.setdefault("age",67)  #return value if found else sets value of key to default..
# Out:
# 67

# %%
student
# Out:
# {'name': 'Alice', 'grade': 'A', 'age': 67}
